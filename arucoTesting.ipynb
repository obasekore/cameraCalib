# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
dictionary = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_6X6_250)
images = []
length = 10
for i in range(length):
    # generate aruco markers
    img = cv2.aruco.drawMarker(dictionary,i,200,1)
    cv2.imwrite("aruco_diction_joint_{}.png".format(i),img)

# %%
img = cv2.imread("aruco_diction.png")

# %%
cv2.imshow("image",img); cv2.waitKey(); cv2.destroyAllWindows()

# %%
# hint about the marker's profile/identity
parameters = cv2.aruco.DetectorParameters_create()
dictionary_1 = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_6X6_250)

# %%
img = cv2.imread("C:\\Users\\OBAS\\Documents\\Python_Scripts\\Python_Scripts\\RL_pybullet\\gym-nao\\gym_nao\\envs\\workdir\\chessboard.tiff")

# %%
img = cv2.imread("C:\\Users\\OBAS\\Documents\\Python_Scripts\\Python_Scripts\\RL_pybullet\\gym-nao\\gym_nao\\envs\\aruco_diction_joint_0.png") 
# gym_nao\envs\aruco_diction_joint_0.png

# %%
cv2.imshow("image",img); cv2.waitKey(); cv2.destroyAllWindows()

# %%
parameters = cv2.aruco.DetectorParameters_create()
dictionary_1 = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_6X6_250)

# %%
# detect marker
markerCorners, markerIds, rejectedCandidates = cv2.aruco.detectMarkers(img,dictionary_1)

# %%
print(markerIds,markerCorners,rejectedCandidates)
# Out:
# [[16]
#  [15]
#  [14]
#  [13]
#  [10]
#  [ 6]
#  [ 3]
#  [ 2]
#  [ 1]
#  [ 0]] [array([[[1457., 1457.],
#         [1685., 1457.],
#         [1685., 1685.],
#         [1457., 1685.]]], dtype=float32), array([[[ 886., 1457.],
#         [1114., 1457.],
#         [1114., 1685.],
#         [ 886., 1685.]]], dtype=float32), array([[[ 314., 1457.],
#         [ 542., 1457.],
#         [ 542., 1685.],
#         [ 314., 1685.]]], dtype=float32), array([[[1743., 1172.],
#         [1971., 1172.],
#         [1971., 1400.],
#         [1743., 1400.]]], dtype=float32), array([[[  28., 1172.],
#         [ 256., 1172.],
#         [ 256., 1400.],
#         [  28., 1400.]]], dtype=float32), array([[[1743.,  600.],
#         [1971.,  600.],
#         [1971.,  828.],
#         [1743.,  828.]]], dtype=float32), array([[[ 28., 600.],
#         [256., 600.],
#         [256., 828.],
#         [ 28., 828.]]], dtype=float32), array([[[1457.,  314.],
#         [1685.,  314.],
#         [1685.,  542.],
# ...

# %%
# visualize the detected marker
# img_clone =  img.copy()
img_clone = cv2.aruco.drawDetectedMarkers(img.copy(), markerCorners, markerIds)
img_reject = cv2.aruco.drawDetectedMarkers(img.copy(), rejectedCandidates)

# %%
plt.imshow(img_clone)

# %%
plt.imshow(img_reject)

# %%
cv2.imshow("image",img_clone); cv2.waitKey(); cv2.destroyAllWindows()

# %%
vid = cv2.VideoCapture(0)
dictionary = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_6X6_250)

frame_height = int(vid.get(4))
frame_width = int(vid.get(3))

videoOut = cv2.VideoWriter("output.avi", cv2.VideoWriter_fourcc('M','J','P','G'), 10, (frame_width, frame_height))

while vid.isOpened():

    ret, frame = vid.read()
    if ret == True:
        
        # detect ArUcO marker
        markerCorners, markerIds, rejectedCandidates = cv2.aruco.detectMarkers(frame,dictionary)
        img_clone =  frame.copy()
        # Display the detected markers
        img_clone = cv2.aruco.drawDetectedMarkers(img_clone, markerCorners, markerIds)
        cv2.imshow("image",np.hstack((frame,img_clone)))#; cv2.waitKey(); cv2.destroyAllWindows()
        videoOut.write(img_clone)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break
vid.release()
videoOut.release()

# %%
vid.release()
cv2.destroyAllWindows()
